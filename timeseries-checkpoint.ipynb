# %%
import numpy as np
import pandas as pd

# %%
ques = pd.read_csv("C:/Users/yukth/Downloads/data-science-for-good-careervillage/questions.csv")

# %%
tags = pd.read_csv("C:/Users/yukth/Downloads/data-science-for-good-careervillage/tags.csv")

# %%
ques
# Out:
#                            questions_id               questions_author_id  \
# 0      332a511f1569444485cf7a7a556a5e54  8f6f374ffd834d258ab69d376dd998f5
# 1      eb80205482e4424cad8f16bc25aa2d9c  acccbda28edd4362ab03fb8b6fd2d67b
# 2      4ec31632938a40b98909416bdd0decff  f2c179a563024ccc927399ce529094b5
# 3      2f6a9a99d9b24e5baa50d40d0ba50a75  2c30ffba444e40eabb4583b55233a5a4
# 4      5af8880460c141dbb02971a1a8369529  aa9eb1a2ab184ebbb00dc01ab663428a
# ...                                 ...                               ...
# 23926  ce1ff7a035d74721a5b7d21105f9ddb6  c1c6e6a8c9df4c02af52eda6fa0c552f
# 23927  7df38c9ded4a4474bb4f9c1f659e1ad1  6ab792d625e14eb2abc14f9a57a450aa
# 23928  63c89317413046f483020585f0cc8dc4  977428d851b24183b223be0eb8619a8c
# 23929  b64ef9cf0d33475ca9c22bdb8749f5a8  82cc74c0e18347e4b68b219e250eb10f
# 23930  1b1ebe9afc5046ccbb328704e88e5cc0  d233c9936cd64363877ffea1feb10c35
#
#                questions_date_added  \
# 0      2016-04-26 11:14:26 UTC+0000
# ...

# %%
tags
# Out:
#        tags_tag_id      tags_tag_name
# 0            27490            college
# 1              461   computer-science
# 2              593  computer-software
# 3            27292           business
# 4            18217             doctor
# ...            ...                ...
# 16264        33855           #zoology
# 16265        20743                zsh
# 16266        21302              zumba
# 16267        19497              zynga
# 16268        32737                 零售
#
# [16269 rows x 2 columns]

# %%
tag_ques = pd.read_csv("C:/Users/yukth/Downloads/data-science-for-good-careervillage/tag_questions.csv")

# %%
tag_ques
# Out:
#        tag_questions_tag_id         tag_questions_question_id
# 0                     28930  cb43ebee01364c68ac61d347a393ae39
# 1                     28930  47f55e85ce944242a5a347ab85a8ffb4
# 2                     28930  ccc30a033a0f4dfdb2eb987012f25792
# 3                     28930  e30b274e48d741f7bf50eb5e7171a3c0
# 4                     28930  3d22742052df4989b311b4195cbb0f1a
# ...                     ...                               ...
# 76548                 39183  72affe86909d49c09761a1d376476c92
# 76549                 39248  5b86153f2b6c46a4801bb39e10e01281
# 76550                 39249  0946a81d511b48c58376fd59058d3b12
# 76551                 39249  b4de8ccfcd874481bfc80ceacb0caac8
# 76552                 39250  0946a81d511b48c58376fd59058d3b12
#
# [76553 rows x 2 columns]

# %%
ques
# Out:
#                            questions_id               questions_author_id  \
# 0      332a511f1569444485cf7a7a556a5e54  8f6f374ffd834d258ab69d376dd998f5
# 1      eb80205482e4424cad8f16bc25aa2d9c  acccbda28edd4362ab03fb8b6fd2d67b
# 2      4ec31632938a40b98909416bdd0decff  f2c179a563024ccc927399ce529094b5
month
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 ques['questions_date_added']=ques.index.month
#
# AttributeError: 'Int64Index' object has no attribute 'month'

# %%
ques['Date'] = pd.to_datetime(ques.Date, format='%Y-%m-%d')

# %%
ques['Month']=ques.index.month
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 ques['Month']=ques.index.month
#
# AttributeError: 'Int64Index' object has no attribute 'month'

# %%
import statsmodels.formula.api as sm
from statsmodels.tsa import tsatools, stattools

# %%
ques['year'] = ques['Date'].dt.year

# %%
ques
# Out:
#                            questions_id               questions_author_id  \
# 6784   38436aadef3d4b608ad089cf53ab0fe7  05444a2f42454327b2ac4b463c0adbe0
# 7937   edb8c179c5d64c9cb812a59a32045f55  05444a2f42454327b2ac4b463c0adbe0
# 21892  333464d7484b43e3866e86096bc4ddb9  05444a2f42454327b2ac4b463c0adbe0
# 5278   4b995e60b99d4ee18346e893e007cb8f  05444a2f42454327b2ac4b463c0adbe0
# 19021  f6b9ca94aed04ba28256492708e74f60  05444a2f42454327b2ac4b463c0adbe0
# ...                                 ...                               ...
# 4342   585c2e18438d431e8976340d6e39d5c7  1154f74f4ac14aaf8ef1b15cdda2b84f
# 5096   473bc96a9c5646c3a464607fb66c296f  965f3afe66b3453dba0366ea28ccc3a0
# 124    9fe651526385412fa8c9d8a817825ff7  008c7ebabbdf4e7382870d172e6e6691
# 8534   333e06afdb0048d19c126ce02f673a89  c445148b5fc8472da00f50b86dfd8faa
# 9858   8ea56755f5c849099bcb85735e042865  44b3515e25454cfb80ed1df3a2a23f61
#
#                questions_date_added  \
# 6784   2011-09-27 15:23:17 UTC+0000
# ...

# %%
ques['month'] = ques['Date'].dt.month

# %%
ques
# Out:
#                            questions_id               questions_author_id  \
# 6784   38436aadef3d4b608ad089cf53ab0fe7  05444a2f42454327b2ac4b463c0adbe0
# 7937   edb8c179c5d64c9cb812a59a32045f55  05444a2f42454327b2ac4b463c0adbe0
# 21892  333464d7484b43e3866e86096bc4ddb9  05444a2f42454327b2ac4b463c0adbe0
# 5278   4b995e60b99d4ee18346e893e007cb8f  05444a2f42454327b2ac4b463c0adbe0
# 19021  f6b9ca94aed04ba28256492708e74f60  05444a2f42454327b2ac4b463c0adbe0
# ...                                 ...                               ...
# 4342   585c2e18438d431e8976340d6e39d5c7  1154f74f4ac14aaf8ef1b15cdda2b84f
# 5096   473bc96a9c5646c3a464607fb66c296f  965f3afe66b3453dba0366ea28ccc3a0
# 124    9fe651526385412fa8c9d8a817825ff7  008c7ebabbdf4e7382870d172e6e6691
# 8534   333e06afdb0048d19c126ce02f673a89  c445148b5fc8472da00f50b86dfd8faa
# 9858   8ea56755f5c849099bcb85735e042865  44b3515e25454cfb80ed1df3a2a23f61
#
#                questions_date_added  \
# 6784   2011-09-27 15:23:17 UTC+0000
# ...

# %%
ques['year'].value_counts().plot(kind='line',figsize=(15, 5))
# Out:
# <Axes: >

# %%
ques['month'].value_counts().plot(kind='line',figsize=(15, 5))
# Out:
# <Axes: >

# %%
ques['year'].value_counts().plot(kind='bar',figsize=(15, 5))
# Out:
# <Axes: >

# %%
ques['month'].value_counts().plot(kind='bar',figsize=(15, 5))
# Out:
# <Axes: >

# %%
ques['Date'].value_counts().plot(kind='line',figsize=(13, 5))
# Out:
# <Axes: >

# %%
ques_tagques_df = ques.merge(tag_ques,left_on='questions_id',right_on='tag_questions_question_id',how='left')
ques_tagques_df.head()
# Out:
#                        questions_id               questions_author_id  \
# 0  38436aadef3d4b608ad089cf53ab0fe7  05444a2f42454327b2ac4b463c0adbe0
# 1  edb8c179c5d64c9cb812a59a32045f55  05444a2f42454327b2ac4b463c0adbe0
# 2  edb8c179c5d64c9cb812a59a32045f55  05444a2f42454327b2ac4b463c0adbe0
# 3  edb8c179c5d64c9cb812a59a32045f55  05444a2f42454327b2ac4b463c0adbe0
# 4  333464d7484b43e3866e86096bc4ddb9  05444a2f42454327b2ac4b463c0adbe0
#
#            questions_date_added  \
# 0  2011-09-27 15:23:17 UTC+0000
# 1  2011-09-27 15:23:54 UTC+0000
# 2  2011-09-27 15:23:54 UTC+0000
# 3  2011-09-27 15:23:54 UTC+0000
# 4  2011-09-27 15:24:27 UTC+0000
#
#                                      questions_title  \
# 0  What should I major in if I want to become an ...
# 1  What is the typical compensation range for a f...
# 2  What is the typical compensation range for a f...
# 3  What is the typical compensation range for a f...
# 4  What are the best ways to prepare for intervie...
#
# ...

# %%
ques_tagques_df_tag_tagsid=ques_tagques_df.merge(tags,left_on='tag_questions_tag_id',right_on='tags_tag_id',how='left')

# %%
ques_tagques_df_tag_tagsid.head()
# Out:
#                        questions_id               questions_author_id  \
# 0  38436aadef3d4b608ad089cf53ab0fe7  05444a2f42454327b2ac4b463c0adbe0
# 1  edb8c179c5d64c9cb812a59a32045f55  05444a2f42454327b2ac4b463c0adbe0
# 2  edb8c179c5d64c9cb812a59a32045f55  05444a2f42454327b2ac4b463c0adbe0
# 3  edb8c179c5d64c9cb812a59a32045f55  05444a2f42454327b2ac4b463c0adbe0
# 4  333464d7484b43e3866e86096bc4ddb9  05444a2f42454327b2ac4b463c0adbe0
#
#            questions_date_added  \
# 0  2011-09-27 15:23:17 UTC+0000
# 1  2011-09-27 15:23:54 UTC+0000
# 2  2011-09-27 15:23:54 UTC+0000
# 3  2011-09-27 15:23:54 UTC+0000
# 4  2011-09-27 15:24:27 UTC+0000
#
#                                      questions_title  \
# 0  What should I major in if I want to become an ...
# 1  What is the typical compensation range for a f...
# 2  What is the typical compensation range for a f...
# 3  What is the typical compensation range for a f...
# 4  What are the best ways to prepare for intervie...
#
# ...

# %%
ques_tagques_df_tag_tagsid.isnull().sum()
# Out:
# questions_id                   0
# questions_author_id            0
# questions_date_added           0
# questions_title                0
# questions_body                 0
# Date                           0
# year                           0
# month                          0
# tag_questions_tag_id         643
# tag_questions_question_id    643
# tags_tag_id                  643
# tags_tag_name                643
# dtype: int64

# %%
ques_tagques_df_tag_tagsid.shape
# Out:
# (77196, 12)

# %%
ques_tagques_df_tag_tagsid['tags_tag_name'].value_counts()
# Out:
# college                        3744
# career                         1566
# medicine                       1324
# engineering                    1083
# business                        989
#                                ...
# health-and-beauty                 1
# tattoo-artist                     1
# law-enforcement-internships       1
# chicago-police                    1
# nation                            1
# Name: tags_tag_name, Length: 7091, dtype: int64
